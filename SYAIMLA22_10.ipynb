# %%
import seaborn as sns
import numpy as np
import pandas as pd

sns.set_theme(style="darkgrid")
sns.set_color_codes("pastel")

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
print('Covariance:')
iris.cov(numeric_only=True)
# Out:
# Covariance:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %%
print('Correlation:')
iris.corr(numeric_only=True)
# Out:
# Correlation:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.histplot(bins=8 , data = iris['sepal_length'])
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='Count'>

# %%
sns.boxplot(data = iris)
# Out:
# <AxesSubplot: >

# %%
pd.plotting.parallel_coordinates(iris, 'species')
# Out:
# <AxesSubplot: >

# %%
# In this Python program, we begin by importing the Pandas library to facilitate data manipulation and analysis.
# The subsequent step involves loading the IRIS flower dataset from a public source using the read_csv function,
# providing us with a foundational dataset for analysis. To gain a rapid overview, the program displays the initial rows of the dataset.
# the describe function is employed to compute and present comprehensive summary statistics for numerical columns,
# offering insights into central tendencies and variations within the data. Further exploration involves examining the class
# distribution by counting unique values in the 'class' column. The program also computes and displays a correlation matrix for numerical columns,
# shedding light on potential relationships. To enhance visual understanding, the script generates a box plot
# illustrating the distribution of sepal length grouped by 'class' and a histogram depicting the distribution of petal width,
# adding a graphical dimension to the descriptive statistics.
