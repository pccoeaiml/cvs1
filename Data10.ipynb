# %%
# import seaborn as sns
# import numpy as np
# import pandas as pd

# sns.set_theme(style="darkgrid")
# sns.set_color_codes("pastel")

# %pip install seaborn

# %%
import seaborn as sns
import numpy as np
import pandas as pd

sns.set_theme(style="darkgrid")
sns.set_color_codes("pastel")

# %%
iris=pd.read_csv("IRIS.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
mean=np.max(iris["sepal_length"])
mean
# Out:
# 7.9

# %%
mean=np.max(iris["sepal_width"])
mean
# Out:
# 4.4

# %%
mean=np.max(iris["petal_length"])
mean
# Out:
# 6.9

# %%
mean=np.max(iris["petal_width"])
mean
# Out:
# 2.5

# %%
describe=iris.describe(include='all')
describe
# Out:
#         sepal_length  sepal_width  petal_length  petal_width      species
# count     150.000000   150.000000    150.000000   150.000000          150
# unique           NaN          NaN           NaN          NaN            3
# top              NaN          NaN           NaN          NaN  Iris-setosa
# freq             NaN          NaN           NaN          NaN           50
# mean        5.843333     3.054000      3.758667     1.198667          NaN
# std         0.828066     0.433594      1.764420     0.763161          NaN
# min         4.300000     2.000000      1.000000     0.100000          NaN
# 25%         5.100000     2.800000      1.600000     0.300000          NaN
# 50%         5.800000     3.000000      4.350000     1.300000          NaN
# 75%         6.400000     3.300000      5.100000     1.800000          NaN
# max         7.900000     4.400000      6.900000     2.500000          NaN

# %%
print("Covariance")
iris.cov(numeric_only=True)
# Out:
# Covariance
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.039268      1.273682     0.516904
# sepal_width      -0.039268     0.188004     -0.321713    -0.117981
# petal_length      1.273682    -0.321713      3.113179     1.296387
# petal_width       0.516904    -0.117981      1.296387     0.582414

# %%
print("Histogram: sepal_length")
iris.hist("sepal_length")
# Out:
# Histogram: sepal_length
# array([[<AxesSubplot:title={'center':'sepal_length'}>]], dtype=object)

# %%
sns.boxplot(data=iris)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=iris)
# Out:
# <AxesSubplot:>

# %%
pd.plotting.parallel_coordinates(iris,'species')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=iris)
# Out:
# <AxesSubplot:>

# %%
print("correlation:")
iris.corr(numeric_only=True)
# Out:
# correlation:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.pairplot(iris, hue='species')

# %%
mean=np.median(iris['sepal_length'])
mean
# Out:
# 5.8

# %%
max=np.median(iris[['petal_length','petal_width','sepal_length','sepal_width']])
max
# Out:
# 3.2

# %%
c=np.cov(iris[['petal_length','petal_width','sepal_length','sepal_width']])
c
# Out:
# array([[4.75      , 4.42166667, 4.35333333, ..., 2.915     , 2.475     ,
#         2.6       ],
#        [4.42166667, 4.14916667, 4.055     , ..., 2.95583333, 2.50416667,
#         2.62833333],
#        [4.35333333, 4.055     , 3.99      , ..., 2.68833333, 2.28166667,
#         2.39666667],
#        ...,
#        [2.915     , 2.95583333, 2.68833333, ..., 4.18916667, 3.65083333,
#         3.835     ],
#        [2.475     , 2.50416667, 2.28166667, ..., 3.65083333, 3.20916667,
#         3.375     ],
#        [2.6       , 2.62833333, 2.39666667, ..., 3.835     , 3.375     ,
#         3.55      ]])

# %%
sns.histplot(bins=10,data=iris['sepal_width'])
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>
