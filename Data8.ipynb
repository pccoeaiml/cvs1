# %%
# %pip install seaborn

# %%
import seaborn as sns
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,PowerTransformer,QuantileTransformer
import matplotlib.pyplot as plt
import numpy as np
sns.set_theme(style="darkgrid")

# %%
data=pd.read_csv("IRIS.csv")
iris=data
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
fig,ax=plt.subplots(ncols=2,nrows=2)
sns.histplot(data=iris,x='sepal_length',bins=100,kde=True,hue='species',ax=ax[0,0]).set(title='sepal_length')
# plt.show()
sns.histplot(data=iris,x='sepal_width',bins=100,kde=True,hue='species',ax=ax[0,1]).set(title='sepal_width')
sns.histplot(x = 'petal_length' , data = iris , bins = 100, kde=True, hue='species', ax=ax[1, 0]).set(title='petal_length')
sns.histplot(x = 'petal_width' , data = iris , bins = 100, kde=True, hue='species', ax=ax[1, 1]).set(title='petal_width')
plt.show()
plt.tight_layout()
fig.set_figwidth(7)
fig.set_figheight(7)

# %%
fig,ax=plt.subplots(ncols=2,nrows=2)
sns.boxplot(data=iris,x='sepal_length',hue='species',ax=ax[0,0],legend=True).set(title='sepal_length')
# plt.show()
sns.boxplot(data=iris,x='sepal_width',hue='species',ax=ax[0,1],legend=True).set(title='sepal_width')
sns.boxplot(x = 'petal_length' , data = iris ,  hue='species', ax=ax[1, 0],legend=True).set(title='petal_length')
sns.boxplot(x = 'petal_width' , data = iris ,  hue='species', ax=ax[1, 1],legend=True).set(title='petal_width')
# plt.show()
plt.tight_layout()
fig.set_figwidth(10)
fig.set_figheight(10)

# %%
desc=iris.describe()
desc
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
mean=np.mean(iris['sepal_width'])
mean
# Out:
# 3.0540000000000003

# %%
c=pd.describe_option(include="all")
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 c=pd.describe_option(include="all")
#       2 c
#
# File /lib/python3.11/site-packages/pandas/_config/config.py:263, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     262 def __call__(self, *args, **kwds) -> T:
# --> 263     return self.__func__(*args, **kwds)
#
# TypeError: _describe_option() got an unexpected keyword argument 'include'

# %%
fig,ax=plt.subplots(ncols=2,nrows=1)
sns.scatterplot(data=iris,x='sepal_length',y='sepal_width',hue='species',ax=ax[0]).set(title="1")
sns.scatterplot(data=iris,x='petal_length',y='petal_width',hue='species',ax=ax[1]).set(title="2")

plt.tight_layout()
fig.set_figwidth(10)
fig.set_figheight(10)

# %%
fig,ax=plt.subplots(ncols=1,nrows=2)
sns.lineplot(data=iris,x='sepal_length',y='petal_length',hue='species',ax=ax[0])
sns.lineplot(data=iris,x='sepal_width',y='petal_width',hue='species',ax=ax[1])

plt.tight_layout()
fig.set_figwidth(10)
fig.set_figheight(10)

# %%
sns.kdeplot(data=iris)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxplot(data=iris)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=iris,x='sepal_length',hue='species',palette="muted")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='count'>
